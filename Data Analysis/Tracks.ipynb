# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/Users/Nathan Gong/test_out.csv')
df
# Out:
#         frame           x            y  frame.1  eccentricity  area  \
# 0           0  973.540000   313.280000        0      0.931157   100
# 1           0  972.074468   590.574468        0      0.558256    94
# 2           0  970.244681  1061.872340        0      0.934886    94
# 3           0  969.694444   862.333333        0      0.948689    72
# 4           0  965.263889   516.638889        0      0.920959    72
# ...       ...         ...          ...      ...           ...   ...
# 124240    599  282.657143  1188.857143      599      0.925978    70
# 124241    599  263.895833   567.937500      599      0.984963    96
# 124242    599  259.121212   773.878788      599      0.738603    33
# 124243    599  242.019231   635.057692      599      0.908688    52
# 124244    599  207.538462   869.153846      599      0.753674    39
#
#         minor_axis_length  area_eccentricity  particle
# 0                0.364605           0.931157         1
# ...

# %%
for p in df['particle'].unique()[:5]:
    p_data = df[df['particle'] == p]
    plt.plot(p_data['x'], p_data['y'])
